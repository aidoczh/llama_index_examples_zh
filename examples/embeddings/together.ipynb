# %% [markdown]
# <a href="https://colab.research.google.com/github/jerryjliu/llama_index/blob/main/docs/docs/examples/embeddings/together.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="在 Colab 中打开"/></a>

# %% [markdown]
# # Together AI Embeddings（Together AI嵌入）
#
# 本笔记本展示了如何使用`Together AI`进行嵌入。Together AI提供了许多最先进的嵌入模型。
#
# 访问 https://together.ai 并注册以获取API密钥。

# %% [markdown]
# ## 设置

# %% [markdown]
# 如果您在Colab上打开此笔记本，您可能需要安装LlamaIndex 🦙。

# %%
# %pip install llama-index-embeddings-together

# %%
# !pip install llama-index

# %%
# 您可以在嵌入或环境中设置API密钥# 导入os# os.environ["TOEGETHER_API_KEY"] = "your-api-key"from llama_index.embeddings.together import TogetherEmbeddingembed_model = TogetherEmbedding(    model_name="togethercomputer/m2-bert-80M-8k-retrieval", api_key="...")

# %% [markdown]
# ## 获取嵌入向量

# %%
embeddings = embed_model.get_text_embedding("hello world")

# %%
print(len(embeddings))
# Out:
# 768

# %%
print(embeddings[:5])
# Out:
# [-0.11657876, -0.012690996, 0.24342081, 0.32781482, 0.022501636]
