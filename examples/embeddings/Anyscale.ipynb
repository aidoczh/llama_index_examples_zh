# %% [markdown]
# <a href="https://colab.research.google.com/github/jerryjliu/llama_index/blob/main/docs/docs/examples/embeddings/OpenAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="在 Colab 中打开"/></a>

# %% [markdown]
# # Anyscale嵌入
#
# 本指南将向您展示如何通过[Anyscale终端](https://docs.endpoints.anyscale.com/)使用Anyscale嵌入。

# %% [markdown]
# 如果您在colab上打开这个笔记本，您可能需要安装LlamaIndex 🦙。

# %%
# %pip install llama-index-embeddings-anyscale

# %%
# !pip install llama-index

# %%
from llama_index.embeddings.anyscale import AnyscaleEmbedding

embed_model = AnyscaleEmbedding(
    api_key=ANYSCALE_ENDPOINT_TOKEN, embed_batch_size=10
)

# %%
# 基本嵌入示例embeddings = embed_model.get_text_embedding(    "外面下着瓢泼大雨！")print(len(embeddings), embeddings[:10])
