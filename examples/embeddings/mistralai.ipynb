# %% [markdown]
# <a href="https://colab.research.google.com/github/run-llama/llama_index/blob/main/docs/docs/examples/embeddings/mistralai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="在 Colab 中打开"/></a>

# %% [markdown]
# # MistralAI嵌入
#
# 这是一个示例的Markdown文件，用于演示如何翻译Python文件中的Markdown内容。

# %% [markdown]
# 如果您在colab上打开这个笔记本，您可能需要安装LlamaIndex 🦙。

# %%
# %pip install llama-index-embeddings-mistralai

# %%
# !pip install llama-index

# %%
# 导入来自llama_index.embeddings.mistralai的MistralAIEmbedding

# %%
# 获取API密钥并创建嵌入api_key = "YOUR API KEY"  # 你的API密钥model_name = "mistral-embed"embed_model = MistralAIEmbedding(model_name=model_name, api_key=api_key)embeddings = embed_model.get_text_embedding("La Plateforme - The Platform")  # 获取文本嵌入

# %%
print(f"Dimension of embeddings: {len(embeddings)}")
# Out:
# Dimension of embeddings: 1024

# %%
embeddings[:5]
# Out:
# [-0.0299224853515625,
#  -0.0028362274169921875,
#  0.0282745361328125,
#  -0.034759521484375,
#  -0.0017366409301757812]
