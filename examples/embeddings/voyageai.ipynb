# %% [markdown]
# <a href="https://colab.research.google.com/github/run-llama/llama_index/blob/main/docs/docs/examples/embeddings/voyageai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="在 Colab 中打开"/></a>

# %% [markdown]
# # Voyage嵌入

# %% [markdown]
# 如果您在colab上打开这个笔记本，您可能需要安装LlamaIndex 🦙。

# %%
# %pip install llama-index-embeddings-voyageai

# %%
# !pip install llama-index

# %%
# 导入

import os
from llama_index.embeddings.voyageai import VoyageEmbedding

# %%
# 获取API密钥并创建嵌入

model_name = "voyage-law-2"  # 请查看https://docs.voyageai.com/docs/embeddings以获取可用模型
voyage_api_key = os.environ.get("VOYAGE_API_KEY", "your-api-key")

embed_model = VoyageEmbedding(
    model_name=model_name, voyage_api_key=voyage_api_key
)

embeddings = embed_model.get_query_embedding("What is llamaindex?")
