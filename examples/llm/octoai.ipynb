# %% [markdown]
# <a href="https://colab.research.google.com/github/run-llama/llama_index/blob/main/docs/docs/examples/llm/octoai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="在 Colab 中打开"/></a>

# %% [markdown]
# # OctoAI
#
# OctoAI是一个强大的人工智能工具，可以用于处理各种任务和项目。它提供了许多功能和工具，可以帮助用户更高效地完成工作。 OctoAI支持自然语言处理、机器学习、数据分析和其他人工智能领域的功能。

# %% [markdown]
# 如果您在Colab上打开这个笔记本，您可能需要安装LlamaIndex 🦙。

# %%
# %pip install llama-index-llms-octoai
# %pip install llama-index
# %pip install octoai-sdk

# %% [markdown]
# 请在下方填写你的OctoAI API密钥。你可以在[OctoAI](https://octo.ai)获取你的API密钥。
#
# 如果需要更多指导，请参考[这里](https://octo.ai/docs/getting-started/how-to-create-an-octoai-access-token)的说明。

# %%
OCTOAI_API_KEY = ""

# %% [markdown]
# #### 初始化与默认模型的集成

# %%
from llama_index.llms.octoai import OctoAI

octoai = OctoAI(token=OCTOAI_API_KEY)

# %% [markdown]
# #### 使用提示调用`complete`

# %%
response = octoai.complete("Paul Graham is ")
print(response)

# %% [markdown]
# #### 使用消息列表调用`chat`

# %%
from llama_index.core.llms import ChatMessage

messages = [
    ChatMessage(
        role="system",
        content="Below is an instruction that describes a task. Write a response that appropriately completes the request.",
    ),
    ChatMessage(role="user", content="Write a blog about Seattle"),
]
response = octoai.chat(messages)
print(response)

# %% [markdown]
# ## 流式处理

# %% [markdown]
# 使用 `stream_complete` 终端点

# %%
response = octoai.stream_complete("Paul Graham is ")
for r in response:
    print(r.delta, end="")

# %% [markdown]
# 使用`stream_chat`与消息列表

# %%
from llama_index.core.llms import ChatMessage

messages = [
    ChatMessage(
        role="system",
        content="Below is an instruction that describes a task. Write a response that appropriately completes the request.",
    ),
    ChatMessage(role="user", content="Write a blog about Seattle"),
]
response = octoai.stream_chat(messages)
for r in response:
    print(r.delta, end="")

# %% [markdown]
# ## 配置模型

# %%
# 自定义您的API令牌，可以这样做
# 否则它将查找您环境变量中的OCTOAI_TOKEN
octoai = OctoAI(
    model="mistral-7b-instruct", max_tokens=128, token=OCTOAI_API_KEY
)

response = octoai.complete("Paul Graham is ")
print(response)
